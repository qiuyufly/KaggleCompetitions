# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

warnings.simplefilter("ignore")
# Any results you write to the current directory are saved as output.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-67-0da05b725e76> in <module>()
#      11
#      12 import warnings
# ---> 13 from easydl import clear_output
#      14
#      15 # machine learning
#
# ImportError: No module named 'easydl'

# %%
train_data = pd.read_csv("train.csv")
train_data.head()

# %%
grid = sns.FacetGrid(train_data, row='Embarked', height=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
grid.add_legend()
plt.show()

# %%
grid = sns.FacetGrid(train_data, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=.5, ci=None)
grid.add_legend
plt.show()

# %%
g=sns.FacetGrid(train_data,col='Survived',row='Pclass', height=2.2, aspect=1.6)
g.map(plt.hist,'Age',bins=20,alpha=0.5)
plt.show()

# %%
train_data.groupby('SibSp')['Survived'].mean().reset_index().sort_values(by='Survived',ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_data.groupby('Parch')['Survived'].mean().reset_index().sort_values(by='Survived',ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
test_data = pd.read_csv("test.csv")
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.describe(include=['O'])
# Out:
#                              Name   Sex    Ticket            Cabin Embarked
# count                         418   418       418               91      418
# unique                        418     2       363               76        3
# top     Olsson, Mr. Oscar Wilhelm  male  PC 17608  B57 B59 B63 B66        S
# freq                            1   266         5                3      270

# %%
print(train_data.shape)
train_df = train_data.drop(['Ticket', 'Cabin'], axis=1)
test_df = test_data.drop(['Ticket', 'Cabin'], axis=1)
combine = [train_df, test_df]
print(train_df.shape)
train_df.head()
# Out:
# (891, 12)
# (891, 10)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
pd.crosstab(test_df.Title,test_df.Sex)
# Out:
# Sex     female  male
# Title
# Col          0     2
# Dona         1     0
# Dr           0     1
# Master       0    21
# Miss        78     0
# Mr           0   240
# Mrs         72     0
# Ms           1     0
# Rev          0     2

# %%
for dataset in combine:
    dataset['Title'] = dataset.Title.replace(['Lady', 'Countess','Capt', \
    'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked Title
# 0      0   7.2500        S    Mr
# 1      0  71.2833        C   Mrs
# 2      0   7.9250        S  Miss
# 3      0  53.1000        S   Mrs
# 4      0   8.0500        S    Mr

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %%
train_df = train_df.drop(['Name', 'PassengerId'], axis=1)
test_df = test_df.drop(['Name'], axis=1)
combine = [train_df, test_df]
train_df.shape, test_df.shape
# Out:
# ((891, 9), (418, 9))

# %%
train_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    male  22.0      1      0   7.2500        S      1
# 1         1       1  female  38.0      1      0  71.2833        C      3
# 2         1       3  female  26.0      0      0   7.9250        S      2
# 3         1       1  female  35.0      1      0  53.1000        S      3
# 4         0       3    male  35.0      0      0   8.0500        S      1

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
print(type(train_df.Sex[0]))
train_df.head()
# Out:
# <class 'numpy.int32'>
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %%
guess_age = np.zeros((2,3))
for dataset in combine:
    for i in range(0,2):
        for j in range(0,3):
            guess_df = dataset[(dataset['Sex']==i)&(dataset['Pclass']==j+1)]['Age'].dropna()
            age_guess = guess_df.median()
            guess_age[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
    for i in range(0,2):
        for j in range(0,3):
            dataset.loc[dataset['Age'].isnull()&(dataset['Sex']==i)&(dataset['Pclass']==j+1),'Age']=guess_age[i,j]
    
    dataset['Age'] = dataset['Age'].astype(int)

# %%
for dataset in combine:
    dataset['Age'] = pd.cut(dataset['Age'],5,labels=[0,1,2,3,4]).astype(int)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int32
# Age         891 non-null int32
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# Embarked    889 non-null object
# Title       891 non-null int64
# dtypes: float64(1), int32(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
train_df.groupby('Age')['Survived'].mean().reset_index().sort_values(by='Survived',ascending=False)
# Out:
#    Age  Survived
# 0    0  0.550000
# 3    3  0.434783
# 2    2  0.412037
# 1    1  0.337374
# 4    4  0.090909

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

train_df.head()    
train_df.groupby('FamilySize')['Survived'].mean().reset_index().sort_values(by='Survived',ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in combine:
    dataset['IsAlone']=0
    dataset.loc[dataset['FamilySize']==1,'IsAlone']=1
    
train_df.groupby('IsAlone')['Survived'].mean().reset_index()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
train_df = train_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
test_df = test_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
combine = [train_df, test_df]

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  Title  IsAlone
# 0         0       3    0    1   7.2500        S      1        0
# 1         1       1    1    2  71.2833        C      3        0
# 2         1       3    1    1   7.9250        S      2        1
# 3         1       1    1    2  53.1000        S      3        0
# 4         0       3    0    2   8.0500        S      1        1

# %%
for dataset in combine:
    dataset['Age*Pclass']=dataset['Age']*dataset['Pclass']
    
train_df[['Age*Pclass','Age','Pclass']].head(10)
# Out:
#    Age*Pclass  Age  Pclass
# 0           3    1       3
# 1           2    2       1
# 2           3    1       3
# 3           2    2       1
# 4           6    2       3
# 5           3    1       3
# 6           3    3       1
# 7           0    0       3
# 8           3    1       3
# 9           0    0       2

# %%
freq_port = train_df.Embarked.dropna().mode()[0]
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
    dataset['Embarked'] = dataset['Embarked'].map({'S': 0, 'C': 1, 'Q': 2}).astype(int)
train_df.groupby('Embarked')['Survived'].mean().reset_index()
# Out:
#    Embarked  Survived
# 0         0  0.339009
# 1         1  0.553571
# 2         2  0.389610

# %%
test_df['Fare'].fillna(test_df['Fare'].dropna().median(),inplace=True)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int32
# Age            418 non-null int32
# Fare           418 non-null float64
# Embarked       418 non-null int32
# Title          418 non-null int64
# IsAlone        418 non-null int64
# Age*Pclass     418 non-null int64
# dtypes: float64(1), int32(3), int64(5)
# memory usage: 24.6 KB

# %%
for dataset in combine:
    dataset['Fare'] = pd.cut(dataset['Fare'],4,labels=[0,1,2,3]).astype(int)
train_df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Pclass
# 0         0       3    0    1     0         0      1        0           3
# 1         1       1    1    2     0         1      3        0           2
# 2         1       3    1    1     0         0      2        1           3
# 3         1       1    1    2     0         0      3        0           2
# 4         0       3    0    2     0         0      1        1           6
# 5         0       3    0    1     0         2      1        1           3
# 6         0       1    0    3     0         0      1        1           3
# 7         0       3    0    0     0         0      4        0           0
# 8         1       3    1    1     0         0      3        0           3
# 9         1       2    1    0     0         1      3        0           0

# %%
X_train = train_df.drop('Survived', axis=1)
Y_train = train_df['Survived']
X_test = test_df.drop('PassengerId', axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Spilit the training dataset into train and test set
X_train_split, X_test_split, y_train_split, y_test_split = train_test_split(X_train,Y_train,test_size = 0.3, random_state=42)

# Setup the hyperparameter grid
c_space = np.logspace(-5, 8, 15)
param_grid = {'C': c_space}

# Logistic regression
classifier = LogisticRegression()

# Instantiate the GridSearchCV object: logreg_cv
#classifier = GridSearchCV(classifier, param_grid, cv=5)

classifier.fit(X_train_split,y_train_split)

# Print the tuned parameters and score
#print("Tuned Logistic Regression Parameters: {}".format(classifier.best_params_)) 
#print("Best score is {}".format(classifier.best_score_))
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': array([1.00000e-05, 8.48343e-05, 7.19686e-04, 6.10540e-03, 5.17947e-02,
#        4.39397e-01, 3.72759e+00, 3.16228e+01, 2.68270e+02, 2.27585e+03,
#        1.93070e+04, 1.63789e+05, 1.38950e+06, 1.17877e+07, 1.00000e+08])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Guide method: randomForestClassifier
from sklearn.ensemble import RandomForestClassifier

y = train_data["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

# %%
# Evaluation
score = classifier.score(X_test_split,y_test_split)
cv10_score = cross_val_score(classifier,X_test_split,y_test_split,cv=10).mean()
pred_Y_split = classifier.predict(X_test_split)
pred_Y = classifier.predict(X_test)

# ROC curve
y_pred_prob = classifier.predict_proba(X_test_split)[:,1]
fpr, tpr, thresholds = roc_curve(y_test_split, y_pred_prob) # fpr is false positive rate, tpr is true positive rate
roc_area_score = roc_auc_score(y_test_split, y_pred_prob)
cv10_auc = cross_val_score(classifier,X_test_split,y_test_split,cv=10,scoring='roc_auc')

# Print out confusion matrix (precision, recall, F1 score...)
print(confusion_matrix(y_test_split,pred_Y_split))
print(classification_report(y_test_split,pred_Y_split))
print('The score of logistic regression is {}'.format(round(score*100,2)))
print('The cross validation score of logistic regression is {}'.format(round(cv10_score*100,2)))
print("AUC: {}".format(roc_area_score))
print("AUC_CV10: {}".format(cv10_auc))

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
# Out:
# [[131  26]
#  [ 29  82]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       157
#            1       0.76      0.74      0.75       111
#
#    micro avg       0.79      0.79      0.79       268
#    macro avg       0.79      0.79      0.79       268
# weighted avg       0.79      0.79      0.79       268
#
# The score of logistic regression is 79.48
# The cross validation score of logistic regression is 78.78
# AUC: 0.8763986916853158
# AUC_CV10: [0.8671875  0.89772727 0.94602273 0.79829545 0.89488636 0.84943182
#  0.73295455 0.90606061 0.95151515 0.84545455]

# %%
# Output the submission .csv file
output = pd.DataFrame({'PassengerId': test_df.PassengerId, 'Survived': pred_Y})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
# Out:
# C:\Users\28678\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
